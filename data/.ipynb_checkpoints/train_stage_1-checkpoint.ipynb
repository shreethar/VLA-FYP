# %%
import sys
import os
from unsloth import FastVisionModel
import torch
from transformers import TextStreamer
from datasets import load_dataset
from stage_1_datasets_static import build_static_dataset
import json
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777659541.657945   14634 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1777659542.280569   14634 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777659544.377993   14634 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
# ── 1. Load already-downloaded HF datasets (no re-download) ──────────────────
molmoact   = load_dataset("allenai/MolmoAct-Pretraining-Mixture", "auxiliary_trace")["train"]
pixmocap   = load_dataset("allenai/pixmo-cap")["train"]
pixmoama   = load_dataset("allenai/pixmo-ask-model-anything")["train"]
pixmocapqa = load_dataset("allenai/pixmo-cap-qa")["train"]
# ── 2. Build static dataset (runs once, takes a few minutes for RoboVQA scan) ─
#    ShareRobot, RoboFAC, RoboVQA are loaded automatically from data/ folder.
splits = build_static_dataset(molmoact, pixmocap, pixmoama, pixmocapqa)
# splits is a plain dict:  {"train": VLAStaticDataset, "val": ..., "test": ...}
train_ds = splits["train"]
val_ds   = splits["val"]
print(f"Train: {len(train_ds):,}  |  Val: {len(val_ds):,}")
# Out:
# Resolving data files:   0%|          | 0/72 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/165 [00:00<?, ?it/s]
# Loading dataset shards:   0%|          | 0/278 [00:00<?, ?it/s]
# README.md: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# Building static VLA dataset...
#   MolmoAct: 195,622 records
#   ShareRobot Affordance: 6,522 records
#   ShareRobot Planning: 99,985 records
#   RoboVQA: 99,988 records (from 801,388 QA pairs)
#   pixmocap: 50,000 records
#   pixmoama: 49,750 records
#   pixmocapqa: 50,000 records
#   RoboFAC: 48,993 records
#
# Dataset split summary:
#   train:  468,901  (78.0%)
#   val  :   78,714  (13.1%)
#   test :   53,245  (8.9%)
#   total:  600,860
# Train: 468,901  |  Val: 78,714

# %%
# Import the pretrained base model and the tokenizer from Unsloth
model, tokenizer = FastVisionModel.from_pretrained(
    "unsloth/Qwen3.5-4B",
    load_in_4bit = False,
    use_gradient_checkpointing = "unsloth"
)
print("Imported Base Model")
# Out:
# ==((====))==  Unsloth 2026.4.6: Fast Qwen3_5 patching. Transformers: 5.5.4. vLLM: 0.19.1.
#    \\   /|    NVIDIA RTX A4000. Num GPUs = 1. Max memory: 15.992 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 8.6. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.35. FA2 = True]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: QLoRA and full finetuning all not selected. Switching to 16bit LoRA.
# The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# Loading weights:   0%|          | 0/723 [00:00<?, ?it/s]
# Imported Base Model

# %%
# Add LoRA adapters to the model
model = FastVisionModel.get_peft_model(
    model,
    finetune_vision_layers = True,
    finetune_language_layers = True,
    finetune_attention_modules = True,
    finetune_mlp_modules = True,

    r = 16,
    lora_alpha = 16,
    lora_dropout = 0,
    bias = "none",
    random_state = 3047,
    use_rslora = False,
    loftq_config = None,
    target_modules = "all-linear",
)
print("Added LoRA Adapters")
# Out:
# [unsloth_zoo.log|WARNING]Unsloth: Failed to register input-embedding hook for `model.base_model.model.model.visual`: `get_input_embeddings` not auto‑handled for Qwen3_5VisionModel; please override in the subclass.. Falling back to pre-forward hook.
# Added LoRA Adapters

# %%
tokenizer.video_processor.do_sample_frames=False

# %%
total_sample = len(train_ds)
print(f"Total Samples: {total_sample}")
# Out:
# Total Samples: 468901

# %%
i = 15

# %%
sample_data = train_ds[i]
print(f" Dataset: {sample_data['dataset']}")
i += 1
# Out:
#  Dataset: robofac

# %%
# Test on inference
FastVisionModel.for_inference(model)
input_text = tokenizer.apply_chat_template(
    [sample_data["messages"][0]],
    add_generation_prompt = True,
    tokenize = False,
    return_dict = True
)
print("-"*20)
print("Input Text:")
print(input_text)
print("Input Text Ended")
print("-"*20)

inputs = tokenizer.apply_chat_template(
    [sample_data["messages"][0]],
    add_generation_prompt = True,
    tokenize = True,
    return_dict = True,
    return_tensors = "pt",
).to(model.device)
# Out:
# --------------------
# Input Text:
# <|im_start|>user
# <|vision_start|><|video_pad|><|vision_end|>You are a robot manipulation assistant. Answer questions about robot tasks, object affordances, spatial relationships, and manipulation strategies based on the provided image or video frame.
#
# This is a video of a robotic arm performing a task, during which subtask did the error happen? (Your answer should choose one of the following options: ['Grasp the cup.', 'Pull the screwdriver off the table.', 'Grasp the lock.', 'Rotate the box to an upright position.', 'Reach for the mouse.'])<|im_end|>
# <|im_start|>assistant
# <think>
#
# </think>
#
#
# Input Text Ended
# --------------------

# %%
text_streamer = TextStreamer(tokenizer,skip_prompt = True)

# %%
outputs = model.generate(
    **inputs,
    streamer = text_streamer,
    max_new_tokens = 256,
    temperature = 1.5,
    min_p = 0.1,
    use_cache = True
)
# Out:
# Grasp the cup.<|im_end|>
# <|endoftext|>

# %%
print(f"Ground Truth: {sample_data["messages"][1]["content"]}")
# Out:
# Ground Truth: Grasp the cup.

# %% [markdown]
# # Start Training

# %%
from unsloth.trainer import UnslothVisionDataCollator
from trl import SFTTrainer, SFTConfig

# %%
os.environ["WANDB_PROJECT"] = "Final Year Project"  # name your W&B project
os.environ["WANDB_LOG_MODEL"] = "checkpoint"

# %%
FastVisionModel.for_training(model) # Enable for training!

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    data_collator = UnslothVisionDataCollator(model, tokenizer), # Must use!
    train_dataset = train_ds,
    args = SFTConfig(
        per_device_train_batch_size = 1,
        gradient_accumulation_steps = 8,
        warmup_steps = 100,
        # max_steps = 75000,
        num_train_epochs = 1, # Set this instead of max_steps for full training runs
        learning_rate = 1e-5,
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.001,
        lr_scheduler_type = "cosine",
        seed = 3407,
        output_dir = "outputs/stage_1",
        report_to = "wandb",     # For Weights and Biases

        # You MUST put the below items for vision finetuning:
        remove_unused_columns = False,
        dataset_text_field = "",
        dataset_kwargs = {"skip_prepare_dataset": True},
        max_length = 2048,
    ),
)
# Out:
# Unsloth: Model does not have a default image size - using 512

# %%
# @title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = NVIDIA RTX A4000. Max memory = 15.992 GB.
# 9.27 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046}.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 468,901 | Num Epochs = 1 | Total steps = 58,613
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 8
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 8 x 1) = 8
#  "-____-"     Trainable parameters = 38,756,352 of 4,578,021,888 (0.85% trained)
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/ubuntu/.netrc.
# wandb: Currently logged in as: shreethar2004 (shreethar2004-universiti-teknikal-malaysia) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/home/ubuntu/Shree_FYP/data/wandb/run-20260502_030054-o14imo3q</code>
# Syncing run <strong><a href='https://wandb.ai/shreethar2004-universiti-teknikal-malaysia/Final%20Year%20Project/runs/o14imo3q' target="_blank">icy-fog-4</a></strong> to <a href='https://wandb.ai/shreethar2004-universiti-teknikal-malaysia/Final%20Year%20Project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/shreethar2004-universiti-teknikal-malaysia/Final%20Year%20Project' target="_blank">https://wandb.ai/shreethar2004-universiti-teknikal-malaysia/Final%20Year%20Project</a>
#  View run at <a href='https://wandb.ai/shreethar2004-universiti-teknikal-malaysia/Final%20Year%20Project/runs/o14imo3q' target="_blank">https://wandb.ai/shreethar2004-universiti-teknikal-malaysia/Final%20Year%20Project/runs/o14imo3q</a>
# wandb: Detected [huggingface_hub.inference, openai] in use.
# wandb: Use W&B Weave for improved LLM call tracing. Install Weave with `pip install weave` then add `import weave` to the top of your script.
# wandb: For more information, check out the docs at: https://weave-docs.wandb.ai
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='46102' max='58613' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [46102/58613 226:00:27 < 61:20:09, 0.06 it/s, Epoch 0.79/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.100014</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.008157</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.748574</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.153054</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.173517</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.793581</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.840307</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.685029</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.645264</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>3.218878</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>3.176870</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>3.322904</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>2.707450</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>3.633616</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>2.981933</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>3.058117</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>3.650004</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>2.967736</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>2.209866</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>3.551298</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>3.307052</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>3.017337</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>2.706964</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>3.308841</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>3.994266</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>2.419749</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>2.800946</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>2.477419</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>3.053878</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>3.125600</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>2.639304</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>3.404265</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>2.951439</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>2.915723</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>3.061234</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>3.277670</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>2.507811</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>3.227127</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>2.683266</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>2.491038</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>2.991226</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>2.768866</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>2.778714</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>2.574333</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>2.612933</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>2.485576</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>2.758532</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>2.590250</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>2.630877</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>2.861174</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>2.732240</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>2.272291</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>2.709351</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>2.022096</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>2.497625</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>2.458825</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>2.564414</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>2.006591</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>2.054509</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>2.306653</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>2.396464</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>2.425765</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>2.166560</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>2.150909</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>2.060170</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>1.891036</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>2.082550</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>1.964592</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>2.161171</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>2.102056</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>2.243190</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>1.907053</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>1.730008</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>1.841703</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.963653</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>1.878210</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>1.825764</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>1.691653</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>1.605526</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.803746</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>1.898661</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>1.589356</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>1.612815</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>1.698633</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>1.443502</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>1.583164</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>1.687241</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>1.434423</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>1.495869</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.589004</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>1.601459</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>1.489297</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>1.649553</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>1.412153</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>1.477514</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>1.358008</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>1.285117</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>1.322876</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>1.388583</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.391962</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>1.283536</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>1.228426</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>1.259521</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>1.238512</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>1.286238</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>1.090025</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>1.073727</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>1.112527</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>1.309262</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.286949</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>1.317631</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>1.089120</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>1.315944</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>1.092135</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.993413</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>1.002624</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>0.873764</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>1.316940</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>1.063793</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.890731</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>0.911695</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>1.192188</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>0.728159</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>0.769740</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.967514</td
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-500)... Done. 0.4s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-1000)... Done. 0.4s
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-1500)... Done. 0.4s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-2000)... Done. 0.4s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-2500)... Done. 0.4s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-3000)... Done. 0.4s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-3500)... Done. 0.4s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-4000)... Done. 0.4s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-4500)... Done. 0.4s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-5000)... Done. 0.5s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-5500)... Done. 0.4s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-6000)... Done. 0.6s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:3574: DecompressionBombWarning: Image size (119451360 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-6500)... Done. 0.5s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-7000)... Done. 0.3s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-7500)... Done. 0.4s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-8000)... Done. 0.9s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-8500)... Done. 0.7s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-9000)... Done. 0.7s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-9500)... Done. 0.7s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-10000)... Done. 0.8s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-10500)... Done. 0.6s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:3574: DecompressionBombWarning: Image size (100000000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-11000)... Done. 0.5s
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-11500)... Done. 0.5s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-12000)... Done. 0.4s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-12500)... Done. 0.4s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-13000)... Done. 0.5s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-13500)... Done. 0.3s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-14000)... Done. 0.7s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-14500)... Done. 0.9s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-15000)... Done. 0.9s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-15500)... Done. 0.8s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-16000)... Done. 0.7s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:3574: DecompressionBombWarning: Image size (95269504 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-16500)... Done. 1.0s
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-17000)... Done. 0.9s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-17500)... Done. 0.7s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-18000)... Done. 0.9s
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-18500)... Done. 0.9s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/TiffImagePlugin.py:949: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-19000)... Done. 0.7s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-19500)... Done. 0.9s
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-20000)... Done. 0.5s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-20500)... Done. 0.4s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-21000)... Done. 0.6s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-21500)... Done. 0.6s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-22000)... Done. 0.6s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-22500)... Done. 0.6s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-23000)... Done. 0.6s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-23500)... Done. 0.5s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-24000)... Done. 0.6s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-24500)... Done. 0.8s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:3574: DecompressionBombWarning: Image size (149817600 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-25000)... Done. 1.2s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-25500)... Done. 0.8s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-26000)... Done. 0.8s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-26500)... Done. 0.8s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-27000)... Done. 0.8s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-27500)... Done. 0.8s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-28000)... Done. 0.9s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-28500)... Done. 0.7s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-29000)... Done. 0.9s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-29500)... Done. 1.0s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-30000)... Done. 0.9s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-30500)... Done. 0.8s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:3574: DecompressionBombWarning: Image size (106070533 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-31000)... Done. 0.8s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-31500)... Done. 0.9s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-32000)... Done. 0.6s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-32500)... Done. 0.4s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-33000)... Done. 0.9s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-33500)... Done. 1.0s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-34000)... Done. 1.0s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-34500)... Done. 1.0s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-35000)... Done. 0.5s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-35500)... Done. 0.8s
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-36000)... Done. 0.7s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-36500)... Done. 0.6s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-37000)... Done. 0.6s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-37500)... Done. 0.7s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-38000)... Done. 0.5s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-38500)... Done. 0.5s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:3574: DecompressionBombWarning: Image size (100000000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-39000)... Done. 0.5s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-39500)... Done. 0.5s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-40000)... Done. 0.5s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-40500)... Done. 0.5s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-41000)... Done. 0.4s
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-41500)... Done. 0.4s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-42000)... Done. 0.5s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-42500)... Done. 0.6s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-43000)... Done. 0.5s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:3574: DecompressionBombWarning: Image size (100000000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-43500)... Done. 0.5s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-44000)... Done. 0.5s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:3574: DecompressionBombWarning: Image size (130874122 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:3574: DecompressionBombWarning: Image size (108000000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-44500)... Done. 0.4s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-45000)... Done. 0.4s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-45500)... Done. 0.4s
# /home/ubuntu/Shree_FYP/.venv/lib/python3.12/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# wandb: Adding directory to artifact (outputs/stage_1/checkpoint-46000)... Done. 0.8s

# %%
# @title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory / max_memory * 100, 3)
lora_percentage = round(used_memory_for_lora / max_memory * 100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(
    f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training."
)
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # @title Show final memory and time stats
# ----> 2 used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
#       3 used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
#       4 used_percentage = round(used_memory / max_memory * 100, 3)
#       5 lora_percentage = round(used_memory_for_lora / max_memory * 100, 3)
#
# NameError: name 'torch' is not defined

# %% [markdown]
# # Completed Training Stage 1

# %%
iterator = iter(train_data)

# %%
next_sample = next(iterator)

# %%
data = next_sample

# %%
data['dataset']

# %%
data_message = data['messages']

# %%
data_message

# %%
# Test on inference
FastVisionModel.for_inference(model)
input_text = tokenizer.apply_chat_template(
    [data_message[0]],
    add_generation_prompt = True,
    tokenize = False,
    return_dict = True
)
print("-"*20)
print("Input Text:")
print(input_text)
print("Input Text Ended")
print("-"*20)

inputs = tokenizer.apply_chat_template(
    [data_message[0]],
    add_generation_prompt = True,
    tokenize = True,
    return_dict = True,
    return_tensors = "pt",
).to(model.device)

# %%
text_streamer = TextStreamer(tokenizer,skip_prompt = True)

# %%
outputs = model.generate(
    **inputs,
    streamer = text_streamer,
    max_new_tokens = 256,
    temperature = 1.5,
    min_p = 0.1,
    use_cache = True
)
