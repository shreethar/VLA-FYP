# %%
from datasets import load_dataset
from collections import Counter

# %%
ds = load_dataset("shreethar/Stage2-dataset")
# Out:
# README.md:   0%|          | 0.00/629 [00:00<?, ?B/s]
# ...
# Resolving data files:   0%|          | 0/20 [00:00<?, ?it/s]
# ...
# data/train-00000-of-00109.parquet:   0%|          | 0.00/56.7M [00:00<?, ?B/s]
# data/train-00001-of-00109.parquet:   0%|          | 0.00/56.4M [00:00<?, ?B/s]
# data/train-00002-of-00109.parquet:   0%|          | 0.00/57.1M [00:00<?, ?B/s]
# data/train-00003-of-00109.parquet:   0%|          | 0.00/56.5M [00:00<?, ?B/s]
# data/train-00004-of-00109.parquet:   0%|          | 0.00/56.7M [00:00<?, ?B/s]
# data/train-00005-of-00109.parquet:   0%|          | 0.00/55.9M [00:00<?, ?B/s]
# data/train-00006-of-00109.parquet:   0%|          | 0.00/56.9M [00:00<?, ?B/s]
# data/train-00007-of-00109.parquet:   0%|          | 0.00/56.0M [00:00<?, ?B/s]
# data/train-00008-of-00109.parquet:   0%|          | 0.00/56.4M [00:00<?, ?B/s]
# data/train-00009-of-00109.parquet:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# ...

# %%
print(Counter(ds["train"]["dataset"]))
# Out:
# Counter({'robovqa': 8598, 'molmoact': 7679, 'sharerobot_planning': 6773, 'pixmocap': 1526, 'pixmocapqa': 1507, 'pixmoama': 1294, 'sharerobot_affordance': 1039})

# %%
print(Counter(ds["val"]["dataset"]))
# Out:
# Counter({'sharerobot_planning': 2681, 'molmoact': 1056, 'robovqa': 583, 'pixmocapqa': 200, 'pixmocap': 180, 'pixmoama': 171, 'sharerobot_affordance': 129})

# %%
print(Counter(ds["test"]["dataset"]))
# Out:
# Counter({'molmoact': 951, 'robovqa': 614, 'sharerobot_planning': 494, 'pixmocapqa': 192, 'pixmocap': 184, 'pixmoama': 171, 'sharerobot_affordance': 144})
