# %%
from transformers import AutoProcessor, AutoModelForImageTextToText
from peft import PeftModel
import torch
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).

# %%
base_model = "shreethar/stage1_unsloth"
adapter_path = "checkpoints/stage2_decoupled_mini/step_000620/teacher_lora"

# %%
base = AutoModelForImageTextToText.from_pretrained(
    base_model,
    dtype = torch.bfloat16,
    device_map = "auto"
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/723 [00:00<?, ?it/s]

# %%
model = PeftModel.from_pretrained(base, adapter_path)

# %%
merged_model = model.merge_and_unload()

# %%
merged_model.push_to_hub("shreethar/stage2_teacher", token="")
# Out:
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/shreethar/stage2_student_ckpt/commit/7ce3881f66c430a23f12aa0797b97dea59543abb', commit_message='Upload Qwen3_5ForConditionalGeneration', commit_description='', oid='7ce3881f66c430a23f12aa0797b97dea59543abb', pr_url=None, repo_url=RepoUrl('https://huggingface.co/shreethar/stage2_student_ckpt', endpoint='https://huggingface.co', repo_type='model', repo_id='shreethar/stage2_student_ckpt'), pr_revision=None, pr_num=None)
